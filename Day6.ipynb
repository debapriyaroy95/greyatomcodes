# %%
import matplotlib 
import seaborn as sns
import pandas as pd 
pd.options.display.max_columns = 50  # None -> No Restrictions
pd.options.display.max_rows = 100   # None -> Be careful with this 
pd.options.display.max_colwidth = 100
pd.options.display.precision = 3

# %%
ls
# Out:
# sample_data/  WorldHappiness2018_Data.csv

# %%
df = pd.read_csv('WorldHappiness2018_Data.csv')

# %%
df.head(5)
# Out:
#    Rank      Country  Score  ...  Generosity  Perceptions_Of_Corruption  Residual
# 0     1      Finland  7.632  ...       0.192                      0.393     2.988
# 1     2       Norway  7.594  ...       0.286                      0.340     2.723
# 2     3      Denmark  7.555  ...       0.284                      0.408     2.779
# 3     4      Iceland  7.495  ...       0.353                      0.138     2.564
# 4     5  Switzerland  7.487  ...       0.256                      0.357     2.675
#
# [5 rows x 10 columns]

# %%
df[['Rank']]
# Out:
#      Rank
# 0       1
# 1       2
# 2       3
# 3       4
# 4       5
# ..    ...
# 151   152
# 152   153
# 153   154
# 154   155
# 155   156
#
# [156 rows x 1 columns]

# %%
df.isnull().sum()
# Out:
# Rank                            0
# Country                         0
# Score                           0
# GDP_Per_Capita                  0
# Social_Support                  0
# Healthy_Life_Expectancy         0
# Freedom_To_Make_Life_Choices    0
# Generosity                      0
# Perceptions_Of_Corruption       1
# Residual                        1
# dtype: int64

# %%
df.Rank
# Out:
# 0        1
# 1        2
# 2        3
# 3        4
# 4        5
#       ...
# 151    152
# 152    153
# 153    154
# 154    155
# 155    156
# Name: Rank, Length: 156, dtype: int64

# %%
df.Score
# Out:
# 0      7.632
# 1      7.594
# 2      7.555
# 3      7.495
# 4      7.487
#        ...
# 151    3.355
# 152    3.303
# 153    3.254
# 154    3.083
# 155    2.905
# Name: Score, Length: 156, dtype: float64

# %%
import matplotlib.pyplot as plt

# %%
#xaxis = 'Rank' , yaxis = 'Score'

plt.plot(df.Rank,df.Score)

# %%
df.dtypes
# Out:
# Rank                              int64
# Country                          object
# Score                           float64
# GDP_Per_Capita                  float64
# Social_Support                  float64
# Healthy_Life_Expectancy         float64
# Freedom_To_Make_Life_Choices    float64
# Generosity                      float64
# Perceptions_Of_Corruption       float64
# Residual                        float64
# dtype: object

# %%
plt.bar(gdp,height=df.Rank)
# Out:
# <BarContainer object of 156 artists>

# %%
plt.plot(df['Rank'],df['Score'])
plt.show()

# %%
gdp = df.GDP_Per_Capita
life_exp = df.Healthy_Life_Expectancy

# %%
A = plt.plot(df['Rank'],life_exp,"Green")
B = plt.plot(df['Rank'],gdp,color="Red")
plt.title('Rank Comapred with GDP and Life Expectancy')
plt.xlabel('Rank')
plt.legend(['A','B'])
#plt.legend(plt.plot(df['Rank'],gdp,color="Red"))
plt.show()

# %%
plt.hist(df.Score)
plt.show()

# %%
df.columns
# Out:
# Index(['Rank', 'Country', 'Score', 'GDP_Per_Capita', 'Social_Support',
#        'Healthy_Life_Expectancy', 'Freedom_To_Make_Life_Choices', 'Generosity',
#        'Perceptions_Of_Corruption', 'Residual'],
#       dtype='object')

# %%
B = plt.hist(df['Score'],color="Red",edgecolor = 'white',linewidth = 2)
plt.title('Rank Comapred with GDP and Life Expectancy')
plt.xlabel('Score')
plt.legend(['B'])
#plt.legend(plt.plot(df['Rank'],gdp,color="Red"))
plt.show()

# %%
df['Score']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-64-612d52d99c28> in <module>()
# ----> 1 int(df.Score)
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/series.py in wrapper(self)
#     129         if len(self) == 1:
#     130             return converter(self.iloc[0])
# --> 131         raise TypeError("cannot convert the series to " "{0}".format(str(converter)))
#     132
#     133     wrapper.__name__ = "__{name}__".format(name=converter.__name__)
#
# TypeError: cannot convert the series to <class 'int'>

# %%
df["Score"]=df["Score"].apply(int)

# %%
df["Score"] = df.Score.astype('float64')

# %%
df.dtypes
# Out:
# Rank                              int64
# Country                          object
# Score                           float64
# GDP_Per_Capita                  float64
# Social_Support                  float64
# Healthy_Life_Expectancy         float64
# Freedom_To_Make_Life_Choices    float64
# Generosity                      float64
# Perceptions_Of_Corruption       float64
# Residual                        float64
# dtype: object

# %%
count_score =df.Score.value_counts()

# %%
print(count_score.index)
# Out:
# Int64Index([5, 4, 6, 3, 7, 2], dtype='int64')

# %%
A = plt.bar(count_score.index,count_score,color="green")
plt.legend(['A'])
plt.xlabel('Frequency')
plt.ylabel('Score')
plt.show()

# %%
df.Score.value_counts()
# Out:
# 5    50
# 4    41
# 6    34
# 3    17
# 7    13
# 2     1
# Name: Score, dtype: int64

# %%
plt.hist(df.Score)
# Out:
# (array([ 1.,  0., 17.,  0., 41.,  0., 50.,  0., 34., 13.]),
#  array([2. , 2.5, 3. , 3.5, 4. , 4.5, 5. , 5.5, 6. , 6.5, 7. ]),
#  <a list of 10 Patch objects>)

# %%
plt.pie(df.Score.value_counts())
plt.legend()
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
plt.scatter(df.Score,gdp)
plt.grid()
#plt.legend(['A'])
#plt.xlabel('Score')
#plt.ylabel('gdp')
plt.show()

# %%
df.columns
# Out:
# Index(['Rank', 'Country', 'Score', 'GDP_Per_Capita', 'Social_Support',
#        'Healthy_Life_Expectancy', 'Freedom_To_Make_Life_Choices', 'Generosity',
#        'Perceptions_Of_Corruption', 'Residual'],
#       dtype='object')

# %%
df.boxplot('Score')
plt.boxplot(gdp)
plt.show()

# %%
import numpy as np

# %%
np1= np.random.rand(10,10)

# %%
print(np1)
# Out:
# [[2.20144350e-01 1.33826881e-01 7.01405246e-02 1.88063840e-01
#   5.94445218e-01 4.35691814e-01 1.72106286e-01 5.11096726e-01
#   7.45389500e-01 5.19029059e-01]
#  [2.32206747e-01 7.71848933e-01 3.61885562e-01 7.19055013e-01
#   3.27749573e-01 3.79381133e-01 5.52860326e-01 5.26144366e-01
#   9.14155244e-01 6.33597843e-01]
#  [5.59340137e-02 4.50361190e-01 3.57578520e-01 9.17810747e-01
#   4.28434519e-02 1.48323688e-01 1.55754638e-01 9.62842795e-01
#   9.77977941e-03 9.89219515e-01]
#  [6.84101286e-01 1.23697826e-01 1.72929201e-01 3.11012206e-01
#   4.35413560e-01 2.17025365e-01 8.35061672e-01 5.23694245e-01
#   7.32893717e-01 4.40234365e-04]
#  [8.15618480e-01 8.78797834e-01 9.87723102e-02 7.47296172e-01
#   6.03726577e-01 3.66945026e-01 5.25504790e-01 6.43913116e-03
#   9.26540722e-01 9.39888332e-01]
#  [7.69702413e-01 6.49522833e-02 4.34206734e-01 9.51787494e-01
#   5.27743135e-01 8.08303313e-01 8.08605835e-01 3.60007345e-01
#   3.55436680e-02 2.84953494e-01]
# ...

# %%
sns.heatmap(np1,linewidths=1.2)

# %%
sns.heatmap(df[['Score','Rank','GDP_Per_Capita']])

# %%
df.columns
# Out:
# Index(['Rank', 'Country', 'Score', 'GDP_Per_Capita', 'Social_Support',
#        'Healthy_Life_Expectancy', 'Freedom_To_Make_Life_Choices', 'Generosity',
#        'Perceptions_Of_Corruption', 'Residual'],
#       dtype='object')

# %%
df1 = df[['Score','Healthy_Life_Expectancy','GDP_Per_Capita']]

# %%
df.corr()
# Out:
#                                Rank  Score  GDP_Per_Capita  Social_Support  \
# Rank                          1.000 -0.992          -0.804          -0.737
# Score                        -0.992  1.000           0.801           0.746
# GDP_Per_Capita               -0.804  0.801           1.000           0.672
# Social_Support               -0.737  0.746           0.672           1.000
# Healthy_Life_Expectancy      -0.778  0.775           0.844           0.667
# Freedom_To_Make_Life_Choices -0.531  0.544           0.322           0.411
# Generosity                   -0.102  0.135          -0.014           0.017
# Perceptions_Of_Corruption    -0.371  0.405           0.311           0.218
# Residual                     -0.536  0.543           0.054           0.082
#
#                               Healthy_Life_Expectancy  \
# Rank                                           -0.778
# Score                                           0.775
# ...

# %%
sns.heatmap(df1.corr())

# %%
sns.heatmap(df.corr())

# %%
count_score2 =df.Rank.value_counts()
A = plt.bar(count_score.index,count_score,color="green")
B = plt.bar(count_score2.index,count_score2,color="Red")

plt.legend(['A','B'])
plt.xlabel('Frequency')
plt.ylabel('Score')
plt.show()

# %%
sns.set(style ="whitegrid")
tips = sns.load_dataset("tips")
ax = sns.violinplot(x=df[['Score','Healthy_Life_Expectancy','GDP_Per_Capita']])

# %%
tips.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')

# %%
ax = sns.violinplot(x=tips[['total_bill', 'tip','size']])

# %%
ax = sns.violinplot(x=tips[['total_bill', 'tip']])

# %%
ax = sns.violinplot(x="day",y="total_bill",data = tips)

# %%
tips.day.unique()
# Out:
# [Sun, Sat, Thur, Fri]
# Categories (4, object): [Sun, Sat, Thur, Fri]

# %%
a = tips[tips['day'] == 'Thur']
sns.violinplot(x=a.total_bill)

# %%
ax = sns.violinplot(x=tips.day,y=tips.total_bill)

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
ax = sns.violinplot(x=tips.day,y=tips.total_bill,hue = tips.smoker,palette="muted")

# %%
ax = sns.violinplot(x=tips.day,y=tips.total_bill,hue = tips.smoker)

# %%
ax = sns.violinplot(x=tips.day,y=tips.total_bill,hue = tips.size,palette="muted")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /usr/local/lib/python3.6/dist-packages/seaborn/utils.py in categorical_order(values, order)
#     525             try:
# --> 526                 order = values.cat.categories
#     527             except (TypeError, AttributeError):
#
# AttributeError: 'numpy.int64' object has no attribute 'cat'
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# /usr/local/lib/python3.6/dist-packages/seaborn/utils.py in categorical_order(values, order)
#     528                 try:
# --> 529                     order = values.unique()
#     530                 except AttributeError:
#
# AttributeError: 'numpy.int64' object has no attribute 'unique'
#
# During handling of the above exception, another exception occurred:
#
# ...

# %%
tips.size.unique()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-215-628b245d71fa> in <module>()
# ----> 1 tips.size.unique()
#
# AttributeError: 'numpy.int64' object has no attribute 'unique'

# %%
tips.dtypes
# Out:
# total_bill     float64
# tip            float64
# sex           category
# smoker        category
# day           category
# time          category
# size             int64
# dtype: object

# %%
df.Country.value_counts(sort = True)
# Out:
# Bulgaria              1
# Nicaragua             1
# Colombia              1
# Kyrgyzstan            1
# Kenya                 1
#                      ..
# Uruguay               1
# Greece                1
# Gabon                 1
# Dominican Republic    1
# Guatemala             1
# Name: Country, Length: 156, dtype: int64

# %%
df.columns
# Out:
# Index(['Rank', 'Country', 'Score', 'GDP_Per_Capita', 'Social_Support',
#        'Healthy_Life_Expectancy', 'Freedom_To_Make_Life_Choices', 'Generosity',
#        'Perceptions_Of_Corruption', 'Residual'],
#       dtype='object')

# %%
df[(df['Country']=='Norway')|(df['Country']=='India')|(df['Country']=='Colombia')]
# Out:
#      Rank   Country  Score  GDP_Per_Capita  Social_Support  \
# 1       2    Norway  7.594           1.456           1.582
# 36     37  Colombia  6.260           0.960           1.439
# 132   133     India  4.190           0.721           0.747
#
#      Healthy_Life_Expectancy  Freedom_To_Make_Life_Choices  Generosity  \
# 1                      0.861                         0.686       0.286
# 36                     0.635                         0.531       0.099
# 132                    0.485                         0.539       0.172
#
#      Perceptions_Of_Corruption  Residual
# 1                        0.340     2.723
# 36                       0.039     2.596
# 132                      0.093     1.526

# %%
tips[tips['day'] == 'Thur']

# %%
ax = sns.violinplot(x=tips.day,y=tips.total_bill,hue = tips.smoker,palette="muted",split = True)

# %%
ax = sns.violinplot(x=tips.day,y=tips.total_bill,hue = tips.smoker,palette="muted",split = True,=tips.day)

# %%
tips.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')

# %%
###https://seaborn.pydata.org/tutorial.html

# %% [markdown]
# https://seaborn.pydata.org/tutorial.html
